# %%
#Google Drive
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#MTA Delay information file
from google.colab import files
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/MTA_LIRR_Systemwide_Delays__Beginning_2015.csv')

# %%
df.head()
# Out:
#   ServiceDate              DelayCategory  NoofTrains
# 0  06/01/2022       3rd Party Operations          51
# 1  06/01/2022           Capital Projects          48
# 2  06/01/2022                  Customers         149
# 3  06/01/2022    Engineering (Scheduled)          32
# 4  06/01/2022  Engineering (Unscheduled)         211

# %% [markdown]
# - DelayCategory : Represents the identified delay categories
# (3rd Party Operations, Capital Projects,
# Customers, Engineering (Scheduled),
# Engineering (Unscheduled), Maintenance of
# Equipment, Police, Special Events,
# Transportation, Weather & Environmental,
# and Other)
# - NoofTrains : The number of train delays per category and
# time period.

# %% [markdown]
# ###Plot graph by Delay Reasons

# %%
grouped_cate = df.groupby("DelayCategory")['NoofTrains'].sum()

# %%
grouped_cate = grouped_data.sort_values(ascending=False)

# Create the bar plot
ax = grouped_data.plot(kind="bar")

# Customize the x-axis labels to prevent overlapping
plt.xticks(rotation=45, fontsize=10, fontstyle='italic', ha='right')  # Adjust rotation angle as needed

# Add labels and title if needed
plt.xlabel("Category")
plt.ylabel("Count")
plt.title("Delayed reasons")

# Show the plot
plt.show()

# %% [markdown]
# ### Plot graph to see how the number of delay changes

# %%
#Checking for datatype of servicedate
column_dtype = df['ServiceDate'].dtype
print(f"The data type of 'column_name' is {column_dtype}")
# Out:
# The data type of 'column_name' is object

# %%
#Change the format of ServiceDate into date
df['ServiceDatetime'] = pd.to_datetime(df['ServiceDate'], format='%m/%d/%Y')

# %%
#Check
df
# Out:
#     ServiceDate              DelayCategory  NoofTrains ServiceDatetime
# 0    06/01/2022       3rd Party Operations          51      2022-06-01
# 1    06/01/2022           Capital Projects          48      2022-06-01
# 2    06/01/2022                  Customers         149      2022-06-01
# 3    06/01/2022    Engineering (Scheduled)          32      2022-06-01
# 4    06/01/2022  Engineering (Unscheduled)         211      2022-06-01
# ..          ...                        ...         ...             ...
# 985  01/01/2015    Engineering (Scheduled)           6      2015-01-01
# 986  01/01/2015  Engineering (Unscheduled)         123      2015-01-01
# 987  01/01/2015                  Customers         190      2015-01-01
# 988  01/01/2015           Capital Projects           1      2015-01-01
# 989  01/01/2015       3rd Party Operations         238      2015-01-01
#
# [990 rows x 4 columns]

# %%
#groupby servicedatetime and sum the number of the delayed trains
group_delay = df.groupby("ServiceDatetime")["NoofTrains"].sum()

# %%
group_delay.head()
# Out:
# ServiceDatetime
# 2015-01-01    1966
# 2015-02-01    2478
# 2015-03-01    2015
# 2015-04-01    1243
# 2015-05-01    1468
# Name: NoofTrains, dtype: int64

# %%
#Plot a graph
plt.plot(group000.index, group000)
plt.xticks(rotation=45, fontsize=10, fontstyle='italic', ha='right')
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Total Numbers of Delay by Time')
# Out:
# Text(0.5, 1.0, 'Total Numbers of Delay by Time')
